# %%
import sys
import os
sys.path.append('../src/')
import utils
import numpy as np

# %%
import streamlit as st

# %%
import pandas as pd

# %%
pd.

# %%
pd.DataFrame({'Model 1': [1,2 ],
 'Model 2': [1, 2]}, index = ['A', 'B'])
# Out:
#    Model 1  Model 2
# A        1        1
# B        2        2

# %%
help(st.button)
# Out:
# Help on method button in module streamlit.delta_generator:
#
# button(label: 'str', key: 'Optional[Key]' = None, help: 'Optional[str]' = None, on_click: 'Optional[WidgetCallback]' = None, args: 'Optional[WidgetArgs]' = None, kwargs: 'Optional[WidgetKwargs]' = None, *, type: "Literal['primary', 'secondary']" = 'secondary', disabled: 'bool' = False, use_container_width: 'bool' = False) -> 'bool' method of streamlit.delta_generator.DeltaGenerator instance
#     Display a button widget.
#
#     Parameters
#     ----------
#     label : str
#         A short label explaining to the user what this button is for.
#         The label can optionally contain Markdown and supports the following
#         elements: Bold, Italics, Strikethroughs, Inline Code, and Emojis.
#
#         This also supports:
#
#         * Emoji shortcodes, such as ``:+1:``  and ``:sunglasses:``.
#           For a list of all supported codes,
#           see https://share.streamlit.io/streamlit/emoji-shortcodes.
#
# ...

# %%
for i in range(1000):
    tmp = np.random.uniform(0, 1000)
    print(np.equal(np.arange(0, tmp, 0.001).shape[0], 
            int((tmp / 0.001) + 1)))
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ...

# %%
int((9.4214 / 0.001) + 1)
# Out:
# 9422

# %%
import ssms
from matplotlib import pyplot as plt

# %%
ssms.config.model_config['ddm']
# Out:
# {'name': 'ddm',
#  'params': ['v', 'a', 'z', 't'],
#  'param_bounds': [[-3.0, 0.3, 0.1, 0.0], [3.0, 2.5, 0.9, 2.0]],
#  'boundary_name': 'constant',
#  'boundary': <function ssms.basic_simulators.boundary_functions.constant(t=0)>,
#  'boundary_params': [],
#  'n_params': 4,
#  'default_params': [0.0, 1.0, 0.5, 0.001],
#  'nchoices': 2,
#  'simulator': <cyfunction ddm_flexbound at 0x16e5b1ff0>}

# %%
out = ssms.basic_simulators.simulator.simulator(model = 'ddm', 
                                          theta = [0.0, 1.0, 0.5, 0.3])

# %%
out['metadata']
# Out:
# {'v': array([0.], dtype=float32),
#  'a': array([1.], dtype=float32),
#  'z': array([0.5], dtype=float32),
#  't': array([0.3], dtype=float32),
#  's': 1.0,
#  'deadline': array([999.], dtype=float32),
#  'delta_t': 0.0010000000474974513,
#  'max_t': 20.0,
#  'n_samples': 1000,
#  'n_trials': 1,
#  'simulator': 'ddm_flexbound',
#  'boundary_fun_type': 'constant',
#  'possible_choices': [-1, 1],
#  'trajectory': array([[ 0.0000000e+00],
#         [ 9.3730288e-03],
#         [ 2.3642525e-02],
#         ...,
#         [-9.9900000e+02],
#         [-9.9900000e+02],
#         [-9.9900000e+02]], dtype=float32),
#  'boundary': array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  'model': 'ddm'}

# %%
import numpy as np
np.maximum(out['metadata']['boundary'], 0)
# Out:
# array([1., 1., 1., ..., 1., 1., 1.], dtype=float32)

# %%
out.
# Out:
# {'v': array([0.], dtype=float32),
#  'a': array([1.], dtype=float32),
#  'z': array([0.5], dtype=float32),
#  't': array([0.3], dtype=float32),
#  's': 1.0,
#  'deadline': array([999.], dtype=float32),
#  'delta_t': 0.0010000000474974513,
#  'max_t': 20.0,
#  'n_samples': 1000,
#  'n_trials': 1,
#  'simulator': 'ddm_flexbound',
#  'boundary_fun_type': 'constant',
#  'possible_choices': [-1, 1],
#  'trajectory': array([[ 0.0000000e+00],
#         [ 9.3730288e-03],
#         [ 2.3642525e-02],
#         ...,
#         [-9.9900000e+02],
#         [-9.9900000e+02],
#         [-9.9900000e+02]], dtype=float32),
#  'boundary': array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  'model': 'ddm'}

# %%
out['rts'].mean()
# Out:
# 1.3404143

# %%
fig, ax = plt.subplots(1,1)
utils.utils.plot_func_model(model_name = 'ddm',
                            theta = [0.0, 1.0, 0.5, 0.3],
                            axis = ax,
                            value_range = [0, 5],
                            n_samples = 5000,
                            ylim = 5,
                            data_color = 'black',
                            add_trajectories = True)

plt.show()
